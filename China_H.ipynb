# %%
import pandas as pd

# %%
excel_file = pd.ExcelFile("T:\EquityOps\Toronto\Free_float_Oct14\HK_final\\1193.HK.xlsx")
df = pd.read_excel(excel_file)

# %%
excel_file.close()

# %%
df
# Out:
#                                 Symbol                               Name  \
# 0                              1193.HK  China Resources Gas Group Limited
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                     Shareholder Name                        Shares Held
# 5   China Resources Group gas Co.,Ltd.                         1407828991
# 6                 JPMorgan Chase & Co.                           20524253
# 7                     He Trade Co.,Ltd                           14470000
# 8                                    0                                  0
# 9                                    0                                  0
# 10                                   0                                  0
# 11                                   0                                  0
# ...
